# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\tsube\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\tsube\anaconda3\lib\site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
from scipy.stats import linregress
import scipy.stats as stats
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 601

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Url and units
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build query URL
query_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=" + units

city_weather = requests.get(query_url)
city_weather = city_weather.json()

# query_url
response = requests.get(query_url + city).json()

# %%
# Creating lists as holding variables

lat = []
lng = []
temp = []
temp_max = []
humidity = []
wind_speed = []
date = []
country = []
cloudiness = []

# %%
# Loop through the list of cities and request for data on each

print("Beginning Data Retrieval")
print("♦" * 45)

count = 0

for idx, city in enumerate(cities):
    count = count + 1

    print(f"Retrieving city record {count}:  {city}")
    
    try:
        response = requests.get(url + "appid=" + weather_api_key + "&q=" + city + "&units=" + units).json()
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        wind_speed.append(response['wind']['speed'])
        date.append(response['dt'])
        country.append(response['sys']['country'])
        cloudiness.append(response['clouds']['all'])

    except KeyError:
        print("City not found. Skipping...")
        lat.append(np.nan)
        lng.append(np.nan)
        temp.append(np.nan)
        temp_max.append(np.nan)
        humidity.append(np.nan)
        wind_speed.append(np.nan)
        date.append(np.nan)
        country.append(np.nan)
        cloudiness.append(np.nan)

print("♦" * 45)
print("Data Retrieval is Complete")
print("♦" * 45)
# Out:
# Beginning Data Retrieval
# ♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦
# Retrieving city record 1:  tuktoyaktuk
# Retrieving city record 2:  qaanaaq
# Retrieving city record 3:  flinders
# Retrieving city record 4:  batemans bay
# Retrieving city record 5:  dikson
# Retrieving city record 6:  souris
# Retrieving city record 7:  kudahuvadhoo
# Retrieving city record 8:  upernavik
# Retrieving city record 9:  skibbereen
# Retrieving city record 10:  cayenne
# Retrieving city record 11:  bluff
# Retrieving city record 12:  new norfolk
# Retrieving city record 13:  port alfred
# Retrieving city record 14:  venezuela
# Retrieving city record 15:  puerto ayora
# Retrieving city record 16:  khatanga
# Retrieving city record 17:  kaitangata
# Retrieving city record 18:  yellowknife
# Retrieving city record 19:  hilo
# Retrieving city record 20:  ushuaia
# Retrieving city record 21:  cape town
# Retrieving city record 22:  illoqqortoormiut
# City not found. Skipping...
# Retrieving city record 23:  rikitea
# Retrieving city record 24:  newport
# Retrieving city record 25:  busselton
# Retrieving city record 26:  simitli
# Retrieving city record 27:  hobart
# Retrieving city record 28:  bereda
# Retrieving city record 29:  lushunkou
# City not found. Skipping...
# Retrieving city record 30:  ballina
# Retrieving city record 31:  butaritari
# Retrieving city record 32:  avarua
# Retrieving city record 33:  kapaa
# Retrieving city record 34:  coahuayana
# Retrieving city record 35:  tiksi
# Retrieving city record 36:  tagbac
# Retrieving city record 37:  albany
# Retrieving city record 38:  kavieng
# Retrieving city record 39:  seymchan
# Retrieving city record 40:  kodiak
# Retrieving city record 41:  saint george
# Retrieving city record 42:  sola
# Retrieving city record 43:  vaini
# Retrieving city record 44:  vreed en hoop
# City not found. Skipping...
# Retrieving city record 45:  chabahar
# Retrieving city record 46:  yarada
# Retrieving city record 47:  ancud
# Retrieving city record 48:  eureka
# Retrieving city record 49:  sisimiut
# Retrieving city record 50:  camacha
# Retrieving city record 51:  bethel
# Retrieving city record 52:  kurilsk
# Retrieving city record 53:  norman wells
# Retrieving city record 54:  punta arenas
# Retrieving city record 55:  deputatskiy
# Retrieving city record 56:  vanimo
# Retrieving city record 57:  tsihombe
# City not found. Skipping...
# Retrieving city record 58:  barrow
# Retrieving city record 59:  vilhena
# Retrieving city record 60:  belushya guba
# City not found. Skipping...
# Retrieving city record 61:  tasiilaq
# Retrieving city record 62:  tunduru
# City not found. Skipping...
# Retrieving city record 63:  vikulovo
# Retrieving city record 64:  samusu
# City not found. Skipping...
# Retrieving city record 65:  arraial do cabo
# Retrieving city record 66:  shieli
# Retrieving city record 67:  hermanus
# Retrieving city record 68:  taolanaro
# City not found. Skipping...
# Retrieving city record 69:  saskylakh
# Retrieving city record 70:  provideniya
# Retrieving city record 71:  bredasdorp
# Retrieving city record 72:  mizan teferi
# Retrieving city record 73:  fortuna
# Retrieving city record 74:  babanusah
# City not found. Skipping...
# Retrieving city record 75:  airai
# Retrieving city record 76:  sauda
# Retrieving city record 77:  grand centre
# City not found. Skipping...
# Retrieving city record 78:  grand gaube
# Retrieving city record 79:  saint-philippe
# Retrieving city record 80:  lebu
# Retrieving city record 81:  manjacaze
# Retrieving city record 82:  kilembe
# Retrieving city record 83:  geraldton
# Retrieving city record 84:  marcona
# City not found. Skipping...
# Retrieving city record 85:  jacareacanga
# Retrieving city record 86:  salalah
# Retrieving city record 87:  kangavar
# Retrieving city record 88:  mahajanga
# Retrieving city record 89:  mahebourg
# Retrieving city record 90:  buta
# Retrieving city record 91:  imbituba
# Retrieving city record 92:  husavik
# Retrieving city record 93:  mataura
# Retrieving city record 94:  hasaki
# Retrieving city record 95:  pevek
# Retrieving city record 96:  florence
# Retrieving city record 97:  san cristobal
# Retrieving city record 98:  atuona
# Retrieving city record 99:  guiyang
# Retrieving city record 100:  clyde river
# Retrieving city record 101:  novyy urengoy
# Retrieving city record 102:  severo-kurilsk
# Retrieving city record 103:  guiratinga
# Retrieving city record 104:  hithadhoo
# Retrieving city record 105:  shimoda
# Retrieving city record 106:  sao filipe
# Retrieving city record 107:  cabo san lucas
# Retrieving city record 108:  port blair
# Retrieving city record 109:  kruisfontein
# Retrieving city record 110:  elban
# Retrieving city record 111:  lavrentiya
# Retrieving city record 112:  haskovo
# Retrieving city record 113:  vangaindrano
# Retrieving city record 114:  luderitz
# Retrieving city record 115:  indiana
# Retrieving city record 116:  caravelas
# Retrieving city record 117:  lompoc
# Retrieving city record 118:  redlands
# Retrieving city record 119:  ribeira grande
# Retrieving city record 120:  kibala
# Retrieving city record 121:  trabzon
# Retrieving city record 122:  baruun-urt
# Retrieving city record 123:  namibe
# Retrieving city record 124:  lipin bor
# Retrieving city record 125:  lethem
# Retrieving city record 126:  ust-bolsheretsk
# City not found. Skipping...
# Retrieving city record 127:  mpika
# Retrieving city record 128:  amderma
# City not found. Skipping...
# Retrieving city record 129:  umm lajj
# Retrieving city record 130:  paralimni
# Retrieving city record 131:  sitka
# Retrieving city record 132:  faanui
# Retrieving city record 133:  pointe michel
# Retrieving city record 134:  aku
# Retrieving city record 135:  carutapera
# Retrieving city record 136:  korla
# Retrieving city record 137:  hidalgotitlan
# Retrieving city record 138:  saint anthony
# Retrieving city record 139:  wadi musa
# Retrieving city record 140:  libreville
# Retrieving city record 141:  bonthe
# Retrieving city record 142:  pisco
# Retrieving city record 143:  togur
# Retrieving city record 144:  semporna
# Retrieving city record 145:  antofagasta
# Retrieving city record 146:  glenwood springs
# Retrieving city record 147:  bichura
# Retrieving city record 148:  del rio
# Retrieving city record 149:  zhuhai
# Retrieving city record 150:  petrolina
# Retrieving city record 151:  mattawa
# Retrieving city record 152:  chokurdakh
# Retrieving city record 153:  bongandanga
# Retrieving city record 154:  rhyl
# Retrieving city record 155:  ust-kamchatsk
# City not found. Skipping...
# Retrieving city record 156:  saleaula
# City not found. Skipping...
# Retrieving city record 157:  rafael reyes
# City not found. Skipping...
# Retrieving city record 158:  solnechnyy
# Retrieving city record 159:  nautla
# Retrieving city record 160:  esperance
# Retrieving city record 161:  naryan-mar
# Retrieving city record 162:  olga
# Retrieving city record 163:  biak
# Retrieving city record 164:  jurmala
# Retrieving city record 165:  honningsvag
# Retrieving city record 166:  quatre cocos
# Retrieving city record 167:  shenzhen
# Retrieving city record 168:  klyuchi
# Retrieving city record 169:  port elizabeth
# Retrieving city record 170:  pacific grove
# Retrieving city record 171:  klaksvik
# Retrieving city record 172:  jamestown
# Retrieving city record 173:  talnakh
# Retrieving city record 174:  pierre
# Retrieving city record 175:  halalo
# City not found. Skipping...
# Retrieving city record 176:  khovu-aksy
# Retrieving city record 177:  el seibo
# Retrieving city record 178:  codrington
# Retrieving city record 179:  castro
# Retrieving city record 180:  thompson
# Retrieving city record 181:  kaduqli
# Retrieving city record 182:  escanaba
# Retrieving city record 183:  port hardy
# Retrieving city record 184:  sioux lookout
# Retrieving city record 185:  mackay
# Retrieving city record 186:  rolim de moura
# City not found. Skipping...
# Retrieving city record 187:  porosozero
# Retrieving city record 188:  adrar
# Retrieving city record 189:  vestmannaeyjar
# Retrieving city record 190:  georgetown
# Retrieving city record 191:  cankuzo
# Retrieving city record 192:  kavaratti
# Retrieving city record 193:  cidreira
# Retrieving city record 194:  ahipara
# Retrieving city record 195:  badarpur
# Retrieving city record 196:  vallenar
# Retrieving city record 197:  along
# Retrieving city record 198:  qui nhon
# Retrieving city record 199:  wani
# Retrieving city record 200:  east london
# Retrieving city record 201:  weiser
# Retrieving city record 202:  attawapiskat
# City not found. Skipping...
# Retrieving city record 203:  saint-augustin
# Retrieving city record 204:  aksarayskiy
# Retrieving city record 205:  tunkas
# Retrieving city record 206:  lyskovo
# Retrieving city record 207:  nouakchott
# Retrieving city record 208:  vavuniya
# Retrieving city record 209:  ponta do sol
# Retrieving city record 210:  san rafael
# Retrieving city record 211:  mukhen
# Retrieving city record 212:  haines junction
# Retrieving city record 213:  aswan
# Retrieving city record 214:  portland
# Retrieving city record 215:  hovd
# Retrieving city record 216:  sinnamary
# Retrieving city record 217:  mar del plata
# Retrieving city record 218:  tuatapere
# Retrieving city record 219:  sibolga
# Retrieving city record 220:  spring valley
# Retrieving city record 221:  baykit
# Retrieving city record 222:  sao gabriel da cachoeira
# Retrieving city record 223:  abu samrah
# Retrieving city record 224:  ojinaga
# Retrieving city record 225:  chuy
# Retrieving city record 226:  nelson bay
# Retrieving city record 227:  makakilo city
# Retrieving city record 228:  ghanzi
# Retrieving city record 229:  narsaq
# Retrieving city record 230:  port lincoln
# Retrieving city record 231:  neiafu
# Retrieving city record 232:  port hawkesbury
# Retrieving city record 233:  fairview
# Retrieving city record 234:  vardo
# Retrieving city record 235:  wanaka
# Retrieving city record 236:  tazovskiy
# Retrieving city record 237:  jahrom
# City not found. Skipping...
# Retrieving city record 238:  byron bay
# Retrieving city record 239:  grand river south east
# City not found. Skipping...
# Retrieving city record 240:  umarkot
# Retrieving city record 241:  tumannyy
# City not found. Skipping...
# Retrieving city record 242:  shenjiamen
# Retrieving city record 243:  khash
# Retrieving city record 244:  natal
# Retrieving city record 245:  san rafael del sur
# Retrieving city record 246:  taltal
# Retrieving city record 247:  gurlan
# Retrieving city record 248:  ormara
# Retrieving city record 249:  dryden
# Retrieving city record 250:  belmonte
# Retrieving city record 251:  kamaishi
# Retrieving city record 252:  jian
# Retrieving city record 253:  longyearbyen
# Retrieving city record 254:  sao joao da barra
# Retrieving city record 255:  sentyabrskiy
# City not found. Skipping...
# Retrieving city record 256:  pauini
# Retrieving city record 257:  cherskiy
# Retrieving city record 258:  tiarei
# Retrieving city record 259:  wajir
# Retrieving city record 260:  umzimvubu
# City not found. Skipping...
# Retrieving city record 261:  etchojoa
# Retrieving city record 262:  asau
# Retrieving city record 263:  yunjinghong
# City not found. Skipping...
# Retrieving city record 264:  walvis bay
# Retrieving city record 265:  nanortalik
# Retrieving city record 266:  vila velha
# Retrieving city record 267:  katsuura
# Retrieving city record 268:  waipawa
# Retrieving city record 269:  camacupa
# Retrieving city record 270:  lasa
# Retrieving city record 271:  abha
# Retrieving city record 272:  carnarvon
# Retrieving city record 273:  praia da vitoria
# Retrieving city record 274:  ambilobe
# Retrieving city record 275:  turayf
# Retrieving city record 276:  yar-sale
# Retrieving city record 277:  drovyanaya
# Retrieving city record 278:  san quintin
# Retrieving city record 279:  liverpool
# Retrieving city record 280:  ilulissat
# Retrieving city record 281:  torbay
# Retrieving city record 282:  grindavik
# Retrieving city record 283:  nabire
# Retrieving city record 284:  barentsburg
# City not found. Skipping...
# Retrieving city record 285:  batagay
# Retrieving city record 286:  touros
# Retrieving city record 287:  aklavik
# Retrieving city record 288:  onguday
# Retrieving city record 289:  jijiga
# Retrieving city record 290:  rawson
# Retrieving city record 291:  half moon bay
# Retrieving city record 292:  pokhara
# Retrieving city record 293:  laguna
# Retrieving city record 294:  waddan
# Retrieving city record 295:  victoria
# Retrieving city record 296:  pak phanang
# Retrieving city record 297:  calinesti
# Retrieving city record 298:  filadelfia
# Retrieving city record 299:  mount pleasant
# Retrieving city record 300:  asfi
# Retrieving city record 301:  sunndalsora
# Retrieving city record 302:  souillac
# Retrieving city record 303:  mys shmidta
# City not found. Skipping...
# Retrieving city record 304:  chatham
# Retrieving city record 305:  moose factory
# Retrieving city record 306:  roebourne
# Retrieving city record 307:  cap malheureux
# Retrieving city record 308:  harihar
# Retrieving city record 309:  zeya
# Retrieving city record 310:  bengkulu
# Retrieving city record 311:  palmer
# Retrieving city record 312:  padang
# Retrieving city record 313:  slave lake
# Retrieving city record 314:  coquimbo
# Retrieving city record 315:  toyooka
# Retrieving city record 316:  temiscaming
# Retrieving city record 317:  mandiana
# Retrieving city record 318:  melfi
# Retrieving city record 319:  manado
# Retrieving city record 320:  esna
# Retrieving city record 321:  djibo
# Retrieving city record 322:  saint-pierre
# Retrieving city record 323:  axim
# Retrieving city record 324:  srednekolymsk
# Retrieving city record 325:  nichinan
# Retrieving city record 326:  knokke-heist
# Retrieving city record 327:  komsomolskiy
# Retrieving city record 328:  saldanha
# Retrieving city record 329:  krasnoselkup
# Retrieving city record 330:  niono
# Retrieving city record 331:  ocos
# Retrieving city record 332:  bardiyah
# Retrieving city record 333:  forestville
# Retrieving city record 334:  necochea
# Retrieving city record 335:  santa isabel do rio negro
# Retrieving city record 336:  atherton
# Retrieving city record 337:  bambous virieux
# Retrieving city record 338:  kermanshah
# Retrieving city record 339:  puga
# Retrieving city record 340:  laranja da terra
# Retrieving city record 341:  qiongshan
# Retrieving city record 342:  te anau
# Retrieving city record 343:  nibong tebal
# Retrieving city record 344:  tonneins
# Retrieving city record 345:  lake city
# Retrieving city record 346:  mount isa
# Retrieving city record 347:  marsh harbour
# Retrieving city record 348:  yumen
# Retrieving city record 349:  coos bay
# Retrieving city record 350:  panalingaan
# Retrieving city record 351:  stornoway
# Retrieving city record 352:  san jose de rio tinto
# Retrieving city record 353:  lodeynoye pole
# Retrieving city record 354:  copiapo
# Retrieving city record 355:  lorengau
# Retrieving city record 356:  methoni
# Retrieving city record 357:  eldikan
# City not found. Skipping...
# Retrieving city record 358:  karpathos
# Retrieving city record 359:  wanning
# Retrieving city record 360:  san policarpo
# Retrieving city record 361:  takoradi
# Retrieving city record 362:  nikolskoye
# Retrieving city record 363:  oistins
# Retrieving city record 364:  santa marta
# Retrieving city record 365:  vanderhoof
# Retrieving city record 366:  puri
# Retrieving city record 367:  atbasar
# Retrieving city record 368:  ginda
# Retrieving city record 369:  the valley
# Retrieving city record 370:  soubre
# Retrieving city record 371:  coihaique
# Retrieving city record 372:  warah
# Retrieving city record 373:  comodoro rivadavia
# Retrieving city record 374:  ternate
# Retrieving city record 375:  papara
# Retrieving city record 376:  fairbanks
# Retrieving city record 377:  villaba
# Retrieving city record 378:  charlestown
# Retrieving city record 379:  ust-nera
# Retrieving city record 380:  bayeux
# Retrieving city record 381:  iqaluit
# Retrieving city record 382:  hamilton
# Retrieving city record 383:  bajil
# Retrieving city record 384:  springbok
# Retrieving city record 385:  galesburg
# Retrieving city record 386:  eenhana
# Retrieving city record 387:  pasighat
# Retrieving city record 388:  tomatlan
# Retrieving city record 389:  ankazobe
# Retrieving city record 390:  richards bay
# Retrieving city record 391:  rexburg
# Retrieving city record 392:  marawi
# Retrieving city record 393:  opuwo
# Retrieving city record 394:  augusto correa
# Retrieving city record 395:  abu dhabi
# Retrieving city record 396:  eyl
# Retrieving city record 397:  berbera
# Retrieving city record 398:  dunedin
# Retrieving city record 399:  harper
# Retrieving city record 400:  flin flon
# Retrieving city record 401:  gemena
# Retrieving city record 402:  praya
# Retrieving city record 403:  vaitupu
# City not found. Skipping...
# Retrieving city record 404:  ryabovo
# Retrieving city record 405:  college
# Retrieving city record 406:  nsanje
# Retrieving city record 407:  adeje
# Retrieving city record 408:  morondava
# Retrieving city record 409:  muros
# Retrieving city record 410:  tucumcari
# Retrieving city record 411:  leningradskiy
# Retrieving city record 412:  bend
# Retrieving city record 413:  yeppoon
# Retrieving city record 414:  elizabeth city
# Retrieving city record 415:  ciudad bolivar
# Retrieving city record 416:  portales
# Retrieving city record 417:  olafsvik
# Retrieving city record 418:  pitiquito
# Retrieving city record 419:  marsa matruh
# Retrieving city record 420:  saint-georges
# Retrieving city record 421:  nizhneyansk
# City not found. Skipping...
# Retrieving city record 422:  bur gabo
# City not found. Skipping...
# Retrieving city record 423:  plettenberg bay
# Retrieving city record 424:  mabaruma
# Retrieving city record 425:  opunake
# Retrieving city record 426:  surt
# Retrieving city record 427:  boffa
# Retrieving city record 428:  bagdarin
# Retrieving city record 429:  keuruu
# Retrieving city record 430:  lagoa
# Retrieving city record 431:  burica
# City not found. Skipping...
# Retrieving city record 432:  kloulklubed
# Retrieving city record 433:  paithan
# Retrieving city record 434:  caraballeda
# Retrieving city record 435:  kakanj
# Retrieving city record 436:  dubti
# Retrieving city record 437:  hami
# Retrieving city record 438:  pacifica
# Retrieving city record 439:  mullaitivu
# City not found. Skipping...
# Retrieving city record 440:  turangi
# Retrieving city record 441:  iracoubo
# Retrieving city record 442:  tome-acu
# City not found. Skipping...
# Retrieving city record 443:  poum
# Retrieving city record 444:  le port
# Retrieving city record 445:  los llanos de aridane
# Retrieving city record 446:  paita
# Retrieving city record 447:  yalta
# Retrieving city record 448:  majene
# Retrieving city record 449:  sorland
# Retrieving city record 450:  bokspits
# City not found. Skipping...
# Retrieving city record 451:  hualmay
# Retrieving city record 452:  acarau
# Retrieving city record 453:  envira
# Retrieving city record 454:  vila franca do campo
# Retrieving city record 455:  banff
# Retrieving city record 456:  tooele
# Retrieving city record 457:  leh
# Retrieving city record 458:  chimore
# Retrieving city record 459:  campobasso
# Retrieving city record 460:  walla walla
# Retrieving city record 461:  vagur
# Retrieving city record 462:  sibu
# Retrieving city record 463:  vilani
# Retrieving city record 464:  inyonga
# Retrieving city record 465:  chumikan
# Retrieving city record 466:  edson
# Retrieving city record 467:  alofi
# Retrieving city record 468:  aldan
# Retrieving city record 469:  storm lake
# Retrieving city record 470:  nicoya
# Retrieving city record 471:  oktyabrskoye
# Retrieving city record 472:  mehamn
# Retrieving city record 473:  palabuhanratu
# City not found. Skipping...
# Retrieving city record 474:  toliary
# City not found. Skipping...
# Retrieving city record 475:  kamal
# Retrieving city record 476:  phan rang
# City not found. Skipping...
# Retrieving city record 477:  fernie
# Retrieving city record 478:  ola
# Retrieving city record 479:  sambava
# Retrieving city record 480:  olutanga
# Retrieving city record 481:  taoudenni
# Retrieving city record 482:  petric
# City not found. Skipping...
# Retrieving city record 483:  san patricio
# Retrieving city record 484:  pelym
# Retrieving city record 485:  cururupu
# Retrieving city record 486:  port keats
# Retrieving city record 487:  yanaul
# Retrieving city record 488:  isla mujeres
# Retrieving city record 489:  zlatoustovsk
# City not found. Skipping...
# Retrieving city record 490:  ewa beach
# Retrieving city record 491:  tapaua
# City not found. Skipping...
# Retrieving city record 492:  aykhal
# Retrieving city record 493:  mount gambier
# Retrieving city record 494:  zaza del medio
# Retrieving city record 495:  kahului
# Retrieving city record 496:  mian channun
# Retrieving city record 497:  lebanon
# Retrieving city record 498:  kupino
# Retrieving city record 499:  nemuro
# Retrieving city record 500:  havelock
# Retrieving city record 501:  charters towers
# Retrieving city record 502:  canatlan
# Retrieving city record 503:  poshekhonye
# Retrieving city record 504:  dwarka
# Retrieving city record 505:  sakakah
# Retrieving city record 506:  bandarbeyla
# Retrieving city record 507:  san luis
# Retrieving city record 508:  jaunpur
# Retrieving city record 509:  mutsamudu
# City not found. Skipping...
# Retrieving city record 510:  shangrao
# Retrieving city record 511:  mozelos
# Retrieving city record 512:  xiongyue
# Retrieving city record 513:  myitkyina
# Retrieving city record 514:  sudzha
# Retrieving city record 515:  mezen
# Retrieving city record 516:  ruteng
# Retrieving city record 517:  atasu
# Retrieving city record 518:  genhe
# Retrieving city record 519:  fukue
# Retrieving city record 520:  sur
# Retrieving city record 521:  burnie
# Retrieving city record 522:  forrest city
# Retrieving city record 523:  ketchikan
# Retrieving city record 524:  manokwari
# Retrieving city record 525:  san ignacio
# Retrieving city record 526:  guerrero negro
# Retrieving city record 527:  mbandaka
# Retrieving city record 528:  nova olimpia
# Retrieving city record 529:  ara
# Retrieving city record 530:  kolobovo
# Retrieving city record 531:  domoni
# Retrieving city record 532:  alta floresta
# Retrieving city record 533:  bambanglipuro
# Retrieving city record 534:  ambovombe
# Retrieving city record 535:  kalyazin
# Retrieving city record 536:  linqiong
# Retrieving city record 537:  bay roberts
# Retrieving city record 538:  barreirinhas
# Retrieving city record 539:  avera
# Retrieving city record 540:  yerbogachen
# Retrieving city record 541:  ryki
# Retrieving city record 542:  borogontsy
# Retrieving city record 543:  kungurtug
# Retrieving city record 544:  boende
# Retrieving city record 545:  zhengjiatun
# Retrieving city record 546:  vaitape
# Retrieving city record 547:  visby
# Retrieving city record 548:  garden city
# Retrieving city record 549:  lata
# Retrieving city record 550:  rabo de peixe
# Retrieving city record 551:  rio grande
# Retrieving city record 552:  stolin
# Retrieving city record 553:  yanam
# Retrieving city record 554:  luanda
# Retrieving city record 555:  la ronge
# Retrieving city record 556:  azuaga
# Retrieving city record 557:  malwan
# City not found. Skipping...
# Retrieving city record 558:  kampot
# Retrieving city record 559:  culiacan
# Retrieving city record 560:  yuanping
# Retrieving city record 561:  antalaha
# Retrieving city record 562:  porto torres
# Retrieving city record 563:  bilibino
# Retrieving city record 564:  karratha
# Retrieving city record 565:  nome
# Retrieving city record 566:  dukat
# Retrieving city record 567:  manaure
# Retrieving city record 568:  chara
# Retrieving city record 569:  jubayl
# City not found. Skipping...
# Retrieving city record 570:  himora
# City not found. Skipping...
# Retrieving city record 571:  morant bay
# Retrieving city record 572:  muravlenko
# Retrieving city record 573:  chipinge
# Retrieving city record 574:  kouango
# Retrieving city record 575:  rosarito
# Retrieving city record 576:  bolungarvik
# City not found. Skipping...
# Retrieving city record 577:  vao
# Retrieving city record 578:  kuche
# City not found. Skipping...
# Retrieving city record 579:  anadyr
# Retrieving city record 580:  port hedland
# Retrieving city record 581:  general pico
# Retrieving city record 582:  sao jose da coroa grande
# Retrieving city record 583:  terrace bay
# Retrieving city record 584:  rio gallegos
# Retrieving city record 585:  high rock
# Retrieving city record 586:  yonago
# Retrieving city record 587:  magistralnyy
# Retrieving city record 588:  hokitika
# Retrieving city record 589:  hervey bay
# Retrieving city record 590:  verkhniy tagil
# Retrieving city record 591:  kapoeta
# Retrieving city record 592:  champerico
# Retrieving city record 593:  moerai
# Retrieving city record 594:  tura
# Retrieving city record 595:  one hundred mile house
# City not found. Skipping...
# Retrieving city record 596:  teguldet
# Retrieving city record 597:  kutum
# Retrieving city record 598:  bucak
# Retrieving city record 599:  farah
# Retrieving city record 600:  glendive
# Retrieving city record 601:  tabiauea
# City not found. Skipping...
# ♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦
# Data Retrieval is Complete
# ♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦♦

# %%
print(len(lat))
print(len(temp))
# Out:
# 601
# 601

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert raw data to dataframe.
city_weather_df = pd.DataFrame({
    "City": cities,
    "Lat": lat,
    "lng": lng,
    "Max Temp": temp_max,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date,
})

# Drop any cities that were skipped because they could not be found using the OpenWeatherMap API.
city_weather_df = city_weather_df.dropna(how="any")

print(city_weather_df.count())
# Out:
# City          552
# Lat           552
# lng           552
# Max Temp      552
# Humidity      552
# Cloudiness    552
# Wind Speed    552
# Country       552
# Date          552
# dtype: int64

# %%
# Export the city data into a .csv file.
city_weather_df.to_csv("./output_data/city_weather_data.csv", index=False)

# Display the DataFrame
weather_df = pd.read_csv("./output_data/city_weather_data.csv")

weather_df
# Out:
#              City      Lat       lng  Max Temp  Humidity  Cloudiness  \
# 0     tuktoyaktuk  69.4541 -133.0374     54.66      58.0       100.0
# 1         qaanaaq  77.4840  -69.3632     40.59     100.0       100.0
# 2        flinders -34.5833  150.8552     65.05      46.0        33.0
# 3    batemans bay -35.7167  150.1833     60.91      31.0        86.0
# 4          dikson  73.5069   80.5464     50.22      90.0       100.0
# ..            ...      ...       ...       ...       ...         ...
# 547      teguldet  57.3064   88.1667     56.82      67.0         6.0
# 548         kutum  14.2000   24.6667     71.13      68.0       100.0
# 549         bucak  37.4592   30.5950     73.44      45.0         0.0
# 550         farah  32.5000   62.5000     72.68      19.0         0.0
# 551      glendive  47.1053 -104.7125     96.49      18.0         0.0
#
#      Wind Speed Country          Date
# 0          8.50      CA  1.628989e+09
# 1          3.53      GL  1.628989e+09
# 2          5.99      AU  1.628989e+09
# 3          2.30      AU  1.628989e+09
# 4         16.93      RU  1.628989e+09
# ..          ...     ...           ...
# 547        3.06      RU  1.628989e+09
# 548        8.95      SD  1.628989e+09
# 549        6.15      TR  1.628989e+09
# 550        7.00      AF  1.628989e+09
# 551        0.43      US  1.628989e+09
#
# [552 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
humidity_100 = weather_df["Humidity"] > 100
humidity_100.value_counts()
# Out:
# False    552
# Name: Humidity, dtype: int64

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# NO OUTLIERS EXISTS

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
date_time = datetime.date(datetime.now())

# Create a scatter plot for latitude vs max temperature.

x_values = weather_df['Lat']
y_values = weather_df['Max Temp']
fig1, ax1 = plt.subplots(figsize=(10,8))
plt.scatter(x_values, y_values, alpha = 0.80, edgecolors = "r", linewidths = 1)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f"Latitude vs Maximum Temperature {date_time}")
plt.grid()
plt.savefig("./output_data/latitude_vs_temperature.png")
plt.show()

print(f"The scatter plot of temperature versus latitude shows that the more favourable temperature range 70F-90F are generally\n" 
f"within the latitude range of -10 to +40. This shows that more suitable range of temperature for human activities are \n" 
f"around the equator lines depending on personal preferences.")
# Out:
# The scatter plot of temperature versus latitude shows that the more favourable temperature range 70F-90F are generally
# within the latitude range of -10 to +40. This shows that more suitable range of temperature for human activities are
# around the equator lines depending on personal preferences.

# %% [markdown]
# # Latitude vs. Humidity Plot

# %%
date_time = datetime.date(datetime.now())

# Create a scatter plot for latitude vs max Humidity.
x_values = weather_df['Lat']
y_values = weather_df['Humidity']
fig1, ax1 = plt.subplots(figsize=(10,8))
plt.scatter(x_values, y_values, alpha = 0.80, edgecolors = "b", linewidths = 1)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f"Latitude vs Humidity {date_time}")
plt.grid()
plt.savefig("./output_data/latitude_vs_Humidity.png")

plt.show()
print(f"The scatter plot of Humidity versus latitude shows that the higher the lattitude towards northen hemisphere\n" 
f"higher the humidity ")
# Out:
# The scatter plot of Humidity versus latitude shows that the higher the lattitude towards northen hemisphere
# higher the humidity

# %% [markdown]
# # Latitude vs. Cloudiness Plot

# %%
date_time = datetime.date(datetime.now())

# Create a scatter plot for latitude vs max Cloudiness.
x_values = weather_df['Lat']
y_values = weather_df['Cloudiness']
fig1, ax1 = plt.subplots(figsize=(10,8))
plt.scatter(x_values, y_values, alpha = 0.80, edgecolors = "g", linewidths = 1)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f"Latitude vs Cloudiness {date_time}")
plt.grid()
plt.savefig("./output_data/latitude_vs_Cloudiness.png")
plt.show()

print(f'Cloudiness seems to be fairly spread out throughout the entire world except in the region between the\n'
      f'latitude of 40-60 degree.')
# Out:
# Cloudiness seems to be fairly spread out throughout the entire world except in the region between the
# latitude of 40-60 degree.

# %% [markdown]
# # Latitude vs. Wind Speed Plot

# %%
ate_time = datetime.date(datetime.now())

# Create a scatter plot for latitude vs Wind Speed.
x_values = weather_df['Lat']
y_values = weather_df['Wind Speed']
fig1, ax1 = plt.subplots(figsize=(10,8))
plt.scatter(x_values, y_values, alpha = 0.80, edgecolors = "y", linewidths = 1)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title(f"Latitude vs Wind Speed {date_time}")
plt.grid()
plt.savefig("./output_data/latitude_vs_Wind Speed.png")
plt.show()

print(f'wind speed seems to be fairly low in the northen hemisphere compared to southern.')
# Out:
# wind speed seems to be fairly low in the northen hemisphere compared to southern.

# %% [markdown]
# # Linear Regression

# %%
# DataFrame for Northen and Southern Hemispheres

northern_hemisphere_weather_df = weather_df.loc[weather_df["Lat"] >= 0]

southern_hemisphere_weather_df = weather_df.loc[weather_df["Lat"] < 0]

# %%
#  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
y_values = northern_hemisphere_weather_df["Max Temp"] 
x_values = northern_hemisphere_weather_df["Lat"] 

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# print(regress_values)

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.title(f"Regression Latitude vs Max Temperature {date_time}")
plt.annotate(line_eq,(10,45),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

plt.savefig("./output_data/regression between latitude vs Temperature (northen).png")
# Show plot
plt.show()

print(f'The Regression chart shows higher the latitude in the northern hemisphere, the max tempearture is getting lower.')
# Out:
# y = -0.42x +87.46
# The r-value is: 0.401189492482491
# The Regression chart shows higher the latitude in the northern hemisphere, the max tempearture is getting lower.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
y_values = southern_hemisphere_weather_df["Max Temp"] 
x_values = southern_hemisphere_weather_df["Lat"] 

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
# print(regress_values)

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.title(f"Regression Latitude vs Max Temperature {date_time}")
plt.annotate(line_eq,(-50,35),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

plt.savefig("./output_data/regression between latitude vs Temperature (southern).png")
# Show plot
plt.show()
print(f'In the southern hemisphere the temperature seems to be fairly correlated with the increase \n'
      f'in latitude as going towards the equator, the temperature gets higher.')
# Out:
# y = 0.66x +79.74
# The r-value is: 0.6335398887633166
# In the southern hemisphere the temperature seems to be fairly correlated with the increase
# in latitude as going towards the equator, the temperature gets higher.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
y_values = northern_hemisphere_weather_df["Humidity"] 
x_values = northern_hemisphere_weather_df["Lat"] 

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
# print(regress_values)

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f"Regression Latitude vs Humidity {date_time}")
plt.annotate(line_eq,(30,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

plt.savefig("./output_data/regression between latitude vs Humidity (northen).png")

# Show plot
plt.show()
print(f'The data shows there is a week correlation between latitude and humidity in the northern hemisphere.')
# Out:
# y = -0.08x +74.56
# The r-value is: 0.0050465680724904715
# The data shows there is a week correlation between latitude and humidity in the northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
y_values = southern_hemisphere_weather_df["Humidity"] 
x_values = southern_hemisphere_weather_df["Lat"] 

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
# print(regress_values)

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f"Regression Latitude vs Humidity {date_time}")
plt.annotate(line_eq,(-50,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

plt.savefig("./output_data/regression between latitude vs Humidity (southern).png")
# Show plot
plt.show()

print(f'The data shows there is a week correlation between latitude and humidity in the southern hemisphere.')
# Out:
# y = 0.1x +72.12
# The r-value is: 0.005663522004674079
# The data shows there is a week correlation between latitude and humidity in the southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
y_values = northern_hemisphere_weather_df["Cloudiness"] 
x_values = northern_hemisphere_weather_df["Lat"] 

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
# print(regress_values)

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f"Regression Latitude vs Cloudiness {date_time}")
plt.annotate(line_eq,(15,10),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

plt.savefig("./output_data/regression between latitude vs Cloudiness (northen).png")

# Show plot
plt.show()

print(f'The data shows there is not at all correlation between latitude and cloudiness in the northern hemisphere.')
# Out:
# y = -0.0x +61.26
# The r-value is: 5.146446811073953e-06
# The data shows there is not at all correlation between latitude and cloudiness in the northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
y_values = southern_hemisphere_weather_df["Cloudiness"] 
x_values = southern_hemisphere_weather_df["Lat"] 

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
# print(regress_values)

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f"Regression Latitude vs Cloudiness {date_time}")
plt.annotate(line_eq,(-50,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

plt.savefig("./output_data/regression between latitude vs Cloudiness (southern).png")

# Show plot
plt.show()

print(f'It shows there is a very week correlation (or not at all) between latitude and cloudiness in the southern hemisphere.')
# Out:
# y = -0.43x +34.84
# The r-value is: 0.020385972324189875
# It shows there is a very week correlation (or not at all) between latitude and cloudiness in the southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
y_values = northern_hemisphere_weather_df["Wind Speed"] 
x_values = northern_hemisphere_weather_df["Lat"] 

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
# print(regress_values)

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title(f"Regression Latitude vs Wind Speed {date_time}")
plt.annotate(line_eq,(22,20),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

plt.savefig("./output_data/regression between latitude vs Wind Speed (northen).png")
# Show plot
plt.show()
# Out:
# y = -0.02x +8.53
# The r-value is: 0.007817453988062401

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
y_values = southern_hemisphere_weather_df["Wind Speed"] 
x_values = southern_hemisphere_weather_df["Lat"] 

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
# print(regress_values)

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title(f"Regression Latitude vs Wind Speed {date_time}")
plt.annotate(line_eq,(-50,25),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

plt.savefig("./output_data/regression between latitude vs Wind Speed (southern).png")

# Show plot
plt.show()
# Out:
# y = -0.04x +6.69
# The r-value is: 0.008243885707456879

# %%
print(f'In both the hemispheres there is a very week correlation (or not at all) between latitude and wind speed.')
# Out:
# In both the hemispheres there is a very week correlation (or not at all) between latitude and wind speed.
